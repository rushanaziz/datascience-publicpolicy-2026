# %%
import os
os.getcwd()
# Out:
# '/Users/rushana/Desktop/datascience-publicpolicy-2026'

# %%
import pandas as pd

demodata = pd.read_csv("/Users/rushana/Documents/GitHub/graspp_2025_spring/data/examples/module_3/democracy_gdp.csv")
demodata.head(4)
# Out:
#   country  year  v2x_frassoc_thick  NGDPDPC  NGDP_RPCH  v2x_pubcorr  \
# 0     AFG  1990              0.063      NaN        NaN        0.556
# 1     AFG  1991              0.068      NaN        NaN        0.556
# 2     AFG  1992              0.134      NaN        NaN        0.645
# 3     AFG  1993              0.159      NaN        NaN        0.843
#
#    v2xnp_regcorr  v2xel_frefair  v2x_freexp  v2elembcap
# 0          0.538          0.069       0.085       -1.65
# 1          0.538          0.069       0.074       -1.65
# 2          0.736          0.028       0.071       -1.65
# 3          0.909          0.000       0.069       -1.65

# %%
ghg = pd.read_csv("/Users/rushana/Documents/GitHub/graspp_2025_spring/data/examples/module_2/ghg.csv")
ghg.tail(3)
# Out:
#             Country  year     emissions
# 11445  GLOBAL TOTAL  2021  51568.250032
# 11446  GLOBAL TOTAL  2022  51968.471601
# 11447  GLOBAL TOTAL  2023  52962.900859

# %%
import requests
import io

def download_worldbank(indicator, countries, date_start, date_end):
    url_base = 'https://api.worldbank.org/v2/'
    country_codes = ';'.join(countries)
    url = f'{url_base}country/{country_codes}/indicator/{indicator}?date={date_start}:{date_end}&per_page=30000'
    response = requests.get(url)
    df = pd.read_xml(io.BytesIO(response.content))
    return df

# %%
gdp_data = download_worldbank(
    indicator='NY.GDP.PCAP.CD',
    date_start= 1990,
    date_end= 2026,
    countries= ["PK"]
)
gdp_data.head(5)
# Out:
#                       indicator   country countryiso3code  date        value  \
# 0  GDP per capita (current US$)  Pakistan             PAK  2025          NaN
# 1  GDP per capita (current US$)  Pakistan             PAK  2024  1478.772780
# 2  GDP per capita (current US$)  Pakistan             PAK  2023  1360.324178
# 3  GDP per capita (current US$)  Pakistan             PAK  2022  1538.322813
# 4  GDP per capita (current US$)  Pakistan             PAK  2021  1455.319224
#
#    unit  obs_status  decimal
# 0   NaN         NaN        1
# 1   NaN         NaN        1
# 2   NaN         NaN        1
# 3   NaN         NaN        1
# 4   NaN         NaN        1

# %%
population_indicator = "SP.POP.TOTL"


country_list = [
    "USA",  # United States of America
    "CAN",  # Canada
    "MEX",  # Mexico
    "GBR",  # United Kingdom of Great Britain and Northern Ireland
    "FRA",  # France
    "DEU",  # Germany (Deutschland)
    "JPN",  # Japan
    "AUS",  # Australia
    "PAK",  #Pakistan
]

pop_data = download_worldbank(
    indicator=population_indicator,
    countries=country_list,
    date_start=1990,
    date_end=2026
)
pop_data.tail(3)
# Out:
#              indicator        country countryiso3code  date        value  \
# 321  Population, total  United States             USA  1992  256514000.0
# 322  Population, total  United States             USA  1991  252981000.0
# 323  Population, total  United States             USA  1990  249623000.0
#
#      unit  obs_status  decimal
# 321   NaN         NaN        0
# 322   NaN         NaN        0
# 323   NaN         NaN        0

# %%
demodata_subset = demodata[["country", "year",]]
demodata_subset.head()
# Out:
#   country  year
# 0     AFG  1990
# 1     AFG  1991
# 2     AFG  1992
# 3     AFG  1993
# 4     AFG  1994

# %%
ddcountrysubset = demodata.query("country == 'PAK'")
ddcountrysubset.head()
# Out:
#      country  year  v2x_frassoc_thick  NGDPDPC  NGDP_RPCH  v2x_pubcorr  \
# 3010     PAK  1990              0.660      NaN        NaN        0.817
# 3011     PAK  1991              0.644      NaN        NaN        0.817
# 3012     PAK  1992              0.644      NaN        NaN        0.817
# 3013     PAK  1993              0.648      NaN        NaN        0.817
# 3014     PAK  1994              0.660      NaN        NaN        0.817
#
#       v2xnp_regcorr  v2xel_frefair  v2x_freexp  v2elembcap
# 3010          0.827          0.278       0.655      -0.514
# 3011          0.827          0.280       0.655      -0.514
# 3012          0.827          0.280       0.655      -0.514
# 3013          0.827          0.281       0.655      -0.514
# 3014          0.827          0.283       0.655      -0.514

# %%
ddyearsubset = demodata.query("year == 1998 and country == 'KOR'")
ddyearsubset.head()
# Out:
#      country  year  v2x_frassoc_thick   NGDPDPC  NGDP_RPCH  v2x_pubcorr  \
# 1037     KOR  1998              0.851  8572.751       -4.9        0.143
# 1038     KOR  1998              0.851  8572.751       -4.9        0.143
# 1039     KOR  1998              0.851  8572.751       -4.9        0.143
# 1040     KOR  1998              0.851  8572.751       -4.9        0.143
# 1041     KOR  1998              0.851  8572.751       -4.9        0.143
#
#       v2xnp_regcorr  v2xel_frefair  v2x_freexp  v2elembcap
# 1037          0.254          0.919       0.923       2.535
# 1038          0.254          0.919       0.923       2.535
# 1039          0.254          0.919       0.923       2.535
# 1040          0.254          0.919       0.923       2.535
# 1041          0.254          0.919       0.923       2.535

# %%
demodata.query("year == 2002")["country"].unique()
# Out:
# array(['AFG', 'ARM', 'AZE', 'Asia (avg)', 'BGD', 'BTN', 'CHN', 'GEO',
#        'HKG', 'IDN', 'IND', 'JPN', 'KAZ', 'KGZ', 'KHM', 'KOR', 'LAO',
#        'LKA', 'MDV', 'MMR', 'MNG', 'MYS', 'NPL', 'PAK', 'PHL', 'PRK',
#        'SGP', 'THA', 'TJK', 'TKM', 'TLS', 'TWN', 'UZB', 'VNM'],
#       dtype=object)

# %%
demodata.query("year == 2016")[["country", "year"]]
# Out:
#          country  year
# 26           AFG  2016
# 61           ARM  2016
# 96           AZE  2016
# 131   Asia (avg)  2016
# 166          BGD  2016
# ...          ...   ...
# 5015         TWN  2016
# 5016         TWN  2016
# 5017         TWN  2016
# 5556         UZB  2016
# 5591         VNM  2016
#
# [160 rows x 2 columns]

# %%
demodata.head(2)
# Out:
#   country  year  v2x_frassoc_thick  NGDPDPC  NGDP_RPCH  v2x_pubcorr  \
# 0     AFG  1990              0.063      NaN        NaN        0.556
# 1     AFG  1991              0.068      NaN        NaN        0.556
#
#    v2xnp_regcorr  v2xel_frefair  v2x_freexp  v2elembcap
# 0          0.538          0.069       0.085       -1.65
# 1          0.538          0.069       0.074       -1.65

# %%
demodata.rename({"country" : "Country"}, axis=1).head(2)
# Out:
#   Country  year  v2x_frassoc_thick  NGDPDPC  NGDP_RPCH  v2x_pubcorr  \
# 0     AFG  1990              0.063      NaN        NaN        0.556
# 1     AFG  1991              0.068      NaN        NaN        0.556
#
#    v2xnp_regcorr  v2xel_frefair  v2x_freexp  v2elembcap
# 0          0.538          0.069       0.085       -1.65
# 1          0.538          0.069       0.074       -1.65

# %%
demodata.rename({"year" : "Year"}, axis=1).head(2)
# Out:
#   country  Year  v2x_frassoc_thick  NGDPDPC  NGDP_RPCH  v2x_pubcorr  \
# 0     AFG  1990              0.063      NaN        NaN        0.556
# 1     AFG  1991              0.068      NaN        NaN        0.556
#
#    v2xnp_regcorr  v2xel_frefair  v2x_freexp  v2elembcap
# 0          0.538          0.069       0.085       -1.65
# 1          0.538          0.069       0.074       -1.65

# %%
demodata[demodata["country"] == "PAK"]
rename_country_map = {
    "AFG" : "Pashtun"
}

demodata.country.replace(rename_country_map)
# Out:
# 0       Pashtun
# 1       Pashtun
# 2       Pashtun
# 3       Pashtun
# 4       Pashtun
#          ...
# 5595        VNM
# 5596        VNM
# 5597        VNM
# 5598        VNM
# 5599        VNM
# Name: country, Length: 5600, dtype: object
